# %%
import numpy as np
import pandas as pd
from catboost import CatBoostRegressor
import re
from parse import parse
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import LogisticRegression

# %%
train_data = pd.read_csv('relevance_train.csv', delimiter='\t', index_col=False)
test_data = pd.read_csv('relevance_test.csv')
queries = pd.read_csv('queries.csv', sep='\t', index_col=False).iloc[:-1]

# %%
queries
# Out:
#      QueryId                                              Query
# 0        1.0  what similarity laws must be obeyed when const...
# 1        2.0  what are the structural and aeroelastic proble...
# 2        4.0  what problems of heat conduction in composite ...
# 3        8.0  can a criterion be developed to show empirical...
# 4        9.0  what chemical kinetic system is applicable to ...
# 5       10.0  what theoretical and experimental guides do we...
# 6       12.0  is it possible to relate the available pressur...
# 7       13.0  what methods -dash exact or approximate -dash ...
# 8       15.0  papers on internal /slip flow/ heat transfer s...
# 9       18.0  are real-gas transport properties for air avai...
# 10      22.0  is it possible to find an analytical,  similar...
# 11      23.0  how can the aerodynamic performance of channel...
# 12      26.0  what is the basic mechanism of the transonic a...
# 13      27.0          papers on shock-sound wave interaction .
# 14      29.0   material properties of photoelastic materials .
# 15      31.0  can the transverse potential flow about a body...
# 16      32.0  can the three-dimensional problem of a transve...
# 17      33.0  are experimental pressure distributions on bod...
# 18      34.0  does there exist a good basic treatment of the...
# 19      35.0  has anyone formally determined the influence o...
# 20      39.0  why does the compressibility transformation fa...
# 21      40.0  did anyone else discover that the turbulent sk...
# 22      41.0  what progress has been made in research on uns...
# 23      49.0  what are the factors which influence the time ...
# 24      50.0  does a practical flow follow the theoretical c...
# 25      51.0  what is a single approximate formula for the d...
# 26      52.0  how is the design of ring or part ring wings b...
# 27      53.0  what application has the linear theory design ...
# 28      54.0  what is the effect of cross sectional shape on...
# 29      55.0  papers on flow visualization on slender conica...
# ..       ...                                                ...
# 195    299.0  the problem of similarity for representative i...
# 196    300.0  how is fatigue damage estimated using the norm...
# 197    301.0  is there any information available on the diff...
# 198    303.0  have non-linear large deflection analyses been...
# 199    304.0  are asymptotic methods sufficiently accurate i...
# 200    306.0  what are the nonequilibrium chemical constitue...
# 201    314.0  how accurate are existing analytical theories ...
# 202    315.0  are simple empirical methods of any use for es...
# 203    316.0  do viscous effects seriously modify pressure d...
# 204    317.0  has anyone investigated theoretically whether ...
# 205    321.0  how do subsonic and transonic flutter data mea...
# 206    323.0  how do large changes in new mass ratio quantit...
# 207    327.0  what is the effect of the shape of the drag po...
# 208    331.0  what are the physical significance and charact...
# 209    332.0  has anyone analytically investigated the stabi...
# 210    333.0  what papers are available on the buckling of e...
# 211    335.0  what effect do thermal stresses have on the co...
# 212    336.0  what is the effect on cylinder buckling of a c...
# 213    338.0  can non-linear shallow shell analysis be reduc...
# 214    339.0  is it possible to predict the shape of a shrou...
# 215    340.0  what investigations have been made of the wave...
# 216    347.0  has anyone investigated the effect of shock ge...
# 217    348.0  what is the heat transfer to a blunt body in t...
# 218    349.0  what are the general effects on flow fields wh...
# 219    352.0  find a calculation procedure applicable to all...
# 220    353.0  papers applicable to this problem (calculation...
# 221    355.0  has anyone investigated the shear buckling of ...
# 222    356.0  papers on shear buckling of unstiffened rectan...
# 223    360.0  in practice, how close to reality are the assu...
# 224    365.0  what design factors can be used to control lif...
#
# [225 rows x 2 columns]

# %%
train_data
# Out:
#      QueryId  DocumentId  Relevance
# 0          1         184          2
# 1          1          29          2
# 2          1          31          2
# 3          1          12          3
# 4          1          51          3
# 5          1         102          3
# 6          1          13          4
# 7          1          14          4
# 8          1          15          4
# 9          1          57          2
# 10         1         378          2
# 11         1         859          2
# 12         1         185          3
# 13         1          30          3
# 14         1          37          3
# 15         1          52          4
# 16         1         142          4
# 17         1         195          4
# 18         1         875          2
# 19         1          56          3
# 20         1          66          3
# 21         1          95          3
# 22         1         462          4
# 23         1         497          3
# 24         1         858          3
# 25         1         876          3
# 26         1         879          3
# 27         1         880          3
# 28         1         486         -1
# 29         2          12          1
# ..       ...         ...        ...
# 960      122         938          2
# 961      122         957          3
# 962      122        1131          3
# 963      122         898         -1
# 964      123         966          2
# 965      123         967          3
# 966      123         941         -1
# 967      124         967          2
# 968      124         968          2
# 969      124         964          3
# 970      124         965          3
# 971      124         941         -1
# 972      125         969          2
# 973      125         970          2
# 974      125         971          2
# 975      125         187          3
# 976      125         973          3
# 977      125         173          3
# 978      125         974          4
# 979      125         177          4
# 980      125         972          2
# 981      125         174          2
# 982      125         997          2
# 983      125         176          3
# 984      125         409          3
# 985      125         946          3
# 986      125         992          3
# 987      125         994          3
# 988      125         995          3
# 989      125         942         -1
#
# [990 rows x 3 columns]

# %%
test_data.DocumentId.max()
# Out:
# 1400

# %%
with open('Documents.csv', 'r') as input_data:
    doc_data = input_data.readlines()
    
documents = []
curr_doc = []

id_re = re.compile('.Id \d+\n')
t_re, a_re, b_re, w_re = [re.compile('.' + x + '\n') for x in ['T', 'A', 'B', 'W']]

for index, curr_line in enumerate(doc_data):
    if id_re.match(curr_line):
        documents.append(curr_doc)
        curr_doc = [int(parse('.Id {}\n', curr_line).fixed[0])]
    elif t_re.match(curr_line) or a_re.match(curr_line) or b_re.match(curr_line) or w_re.match(curr_line):
        curr_doc.append('')
    else:
        curr_doc[-1] += curr_line.strip()  
        
documents = documents[1:]
bad_articles = np.arange(len(documents))[np.array([len(x) for x in documents]) != 5]
for i in bad_articles[::-1]:
    del documents[i]

documents = pd.DataFrame(data=documents, columns=['Id', 'T', 'A', 'B', 'W'])

# %%
documents
# Out:
#         Id                                                  T  \
# 0        1  experimental investigation of the aerodynamics...
# 1        2  simple shear flow past a flat plate in an inco...
# 2        3  the boundary layer in simple shear flow past a...
# 3        4  approximate solutions of the incompressible la...
# 4        5  one-dimensional transient heat conduction into...
# 5        6  one-dimensional transient heat flow in a multi...
# 6        7  the effect of controlled three-dimensional rou...
# 7        8  measurements of the effect of two-dimensional ...
# 8        9  transition studies and skin friction measureme...
# 9       10    the theory of the impact tube at low pressure .
# 10      11  similar solutions in compressible laminar free...
# 11      12  some structural and aerelastic considerations ...
# 12      13       similarity laws for stressing heated wings .
# 13      14  piston theory - a new aerodynamic tool for the...
# 14      15                 on two-dimensional panel flutter .
# 15      16  transformation of the compressible turbulent b...
# 16      17  remarks on the eddy viscosity in compressible ...
# 17      18  the flow field in the diffuser of a radial com...
# 18      19  an investigation of the pressure distribution ...
# 19      20                     generalised-newtonian theory .
# 20      21                    on heat transfer in slip flow .
# 21      22       on slip-flow heat transfer to a flat plate .
# 22      23  skin-friction and heat transfer characteristic...
# 23      24  theory of stagnation point heat transfer in di...
# 24      25  inviscid hypersonic flow over blunt-nosed slen...
# 25      26  inviscid leading-edge effect in hypersonic flow .
# 26      27         newtonian flow theory for slender bodies .
# 27      28  a note on the explosion solution of sedov with...
# 28      29  a simple model study of transient temperature ...
# 29      30  photo-thermoelastic investigation of transient...
# ...    ...                                                ...
# 1366  1370    some remarks on the flat plate boundary layer .
# 1367  1371              axisymmetric free mixing with swirl .
# 1368  1372  on axially symmetric, turbulent, compressible ...
# 1369  1373  nose drag in free-molecule flow and its minimi...
# 1370  1374  theoretical analysis of turbulent mixing of re...
# 1371  1375  an approximate solution for the axisymmetric j...
# 1372  1376   some applications in physics of the p-function .
# 1373  1377  theoretical investigation of the flow field ab...
# 1374  1378  blunt-cone pressure distributions at hypersoni...
# 1375  1379       hypersonic flight and the re-entry problem .
# 1376  1380  the problem of obtaining high lift-drag ratios...
# 1377  1381  effect of mach number on boundary layer transi...
# 1378  1382  the solution of the equations of the laminar b...
# 1379  1383  on the theory of laminar boundary layer involv...
# 1380  1384  a theoretical calculation of the laminar bound...
# 1381  1385  air flow in a separating laminar boundary layer .
# 1382  1386  analysis and calculation by integral methods o...
# 1383  1387  the buckling of a square panel under shear, wh...
# 1384  1388  a process for the step-by-step integration of ...
# 1385  1389   numerical construction of detached shock waves .
# 1386  1390  on the numerical calculation of detached bow s...
# 1387  1391  shock wave and flow field development in hyper...
# 1388  1392  the solution of small displacement, stability ...
# 1389  1393  heat transfer near the forward stagnation poin...
# 1390  1394  stagnation point heat transfer measurements in...
# 1391  1395  low density stagnation point heat transfer mea...
# 1392  1396  shear buckling of clamped and simply-supported...
# 1393  1397  critical shear stress of an infinitely long si...
# 1394  1398  stability of rectangular plates under shear an...
# 1395  1399  buckling of transverse stiffened plates under ...
#
#                                               A  \
# 0                                  brenckman,m.
# 1                                     ting-yili
# 2                                 m. b. glauert
# 3                                      yen,k.t.
# 4                                  wasserman,b.
# 5                                 campbell,w.f.
# 6             van driest,e.r. and mccauley,w.d.
# 7                                klebanoff,p.s.
# 8                                  korkegi,r.h.
# 9                  chambre,p.l. and schaaf,s.a.
# 10                                napolitano,l.
# 11                            bisplinghoff,r.l.
# 12                                   tsien,h.s.
# 13                   ashley,h. and zartarian,g.
# 14                                    fung,y.c.
# 15                                     mager,a.
# 16                    lu ting and paul a. libby
# 17                                 rhyming,i.l.
# 18                                victor zakkay
# 19                                    love,e.s.
# 20                            stephen h. maslen
# 21                  oman,r.a. and scheuing,r.a.
# 22                       seban,r.a. and bond,r.
# 23                    fay,j.a. and riddell,f.r.
# 24                        lees,l. and kubota,t.
# 25                  cheng,h.k. and pallone,a.j.
# 26                                    cole,j.d.
# 27                                 freeman,n.c.
# 28                                   isakson,g.
# 29                   gerard,g. and tramposch,h.
# ...                                         ...
# 1366                lewis,j.a. and carrier,g.f.
# 1367                steiger,m.h. and bloom,m.h.
# 1368                          gdalia kleinstein
# 1369                                   tan,h.s.
# 1370                                 libby,p.a.
# 1371                          gdalia kleinstein
# 1372                               masters,j.i.
# 1373              vaglio-laurin,r. and ferri,a.
# 1374        andrew f. burke and james t. curtis
# 1375                                allen, h.j.
# 1376     clinton e. brown and francis e. mclean
# 1377                                carros,r.j.
# 1378                               hartree,d.r.
# 1379             vonkarman,t. and millikan,c.b.
# 1380                              millikan,c.b.
# 1381                             schubauer,g.b.
# 1382                               morduchow,m.
# 1383                             leggett,d.m.a.
# 1384                                   gills,s.
# 1385                            garabedian,p.r.
# 1386        garabedian,p.r. and liebersten,h.m.
# 1387                            probstein, r.f.
# 1388                               hopkins,h.g.
# 1389                              sibulkin,m.j.
# 1390  neice,s.e., rutkowski,r.w. and chann,k.k.
# 1391              wilson,m.r. and wittliff,c.e.
# 1392                  cook,i.t. and rockey,k.c.
# 1393                  stein,m. and fralich,r.w.
# 1394                                     way,s.
# 1395                                  wang,t.k.
#
#                                                       B  \
# 0                            j. ae. scs. 25, 1958, 324.
# 1     department of aeronautical engineering, rensse...
# 2     department of mathematics, university of manch...
# 3                            j. ae. scs. 22, 1955, 728.
# 4                            j. ae. scs. 24, 1957, 924.
# 5                            j. ae. scs. 25, 1958, 340.
# 6                            j. ae. scs. 27, 1960, 261.
# 7                            j. ae. scs. 22, 1955, 803.
# 8                             j. ae. scs. 23, 1956, 97.
# 9                            j. ae. scs. 15, 1948, 735.
# 10                           j. ae. scs. 23, 1956, 389.
# 11                           j. ae. scs. 23, 1956, 289.
# 12                             j. ae. scs. 20, 1953, 1.
# 13                          j. ae. scs. 23, 1956, 1109.
# 14                           j. ae. scs. 25, 1958, 145.
# 15                           j. ae. scs. 25, 1958, 305.
# 16    polytechnic institute of brooklyn, and general...
# 17                           j. ae. scs. 27, 1960, 798.
# 18    aerodynamics laboratory, polytechnic institute...
# 19                           j. ae. scs. 26, 1959, 314.
# 20    lewis flight propulsion laboratory, naca, clev...
# 21                           j. ae. scs. 26, 1959, 126.
# 22                           j. ae. scs. 18, 1951, 671.
# 23                            j. ae. scs. 25, 1958, 73.
# 24                           j. ae. scs. 24, 1957, 195.
# 25                           j. ae. scs. 23, 1956, 700.
# 26                           j. ae. scs. 24, 1957, 448.
# 27                            j. ae. scs. 27, 1960, 77.
# 28                           j. ae. scs. 24, 1957, 611.
# 29                           j. ae. scs. 26, 1959, 783.
# ...                                                 ...
# 1366                        q. app. math. 7, 1949, 228.
# 1367                                       pibal r.628.
# 1368  polytechnic institute of brooklyn, farmingdale...
# 1369                               j.ae.scs. 1959, 360.
# 1370                            ars jnl. 32, 1962, 388.
# 1371                  polytechnic institute of brooklyn
# 1372                       j.chem.phys. 23, 1955, 1865.
# 1373                         j. ae. scs. 25, 1958, 761.
# 1374  head, research section, and research aerodynam...
# 1375              j. aerospace sce. 25, 217-227, 1958 .
# 1376                      langley research center, nasa
# 1377                              naca rm a56b15, 1956.
# 1378                              arc r + m.2427, 1949.
# 1379                                  naca r.504, 1934.
# 1380                           j. ae. scs. 3, 1936, 91.
# 1381                                  naca r.527, 1935.
# 1382                                 naca r.1245, 1955.
# 1383                              arc r + m.1991, 1941.
# 1384                proc. cam. phil. soc. 47, 1951, 96.
# 1385                        j.math.phys. 36, 1957, 192.
# 1386                         j. ae. scs. 25, 1958, 109.
# 1387                        ars. j. 31, 185-194, 1961 .
# 1388                              arc r + m.2234, 1945.
# 1389                         j. ae. scs. 19, 1952, 570.
# 1390                          j. ae. scs.27, 1960, 387.
# 1391                            ars jnl. 32, 1962, 275.
# 1392                         aero. quart. 13, 1962, 41.
# 1393                                naca tn.1851, 1949.
# 1394                       j. app. mech. 3, 1936, a131.
# 1395                          j.app.mech. 3,1947, a269.
#
#                                                       W
# 0     experimental investigation of the aerodynamics...
# 1     simple shear flow past a flat plate in an inco...
# 2     the boundary layer in simple shear flow past a...
# 3     approximate solutions of the incompressible la...
# 4     one-dimensional transient heat conduction into...
# 5     one-dimensional transient heat flow in a multi...
# 6     the effect of controlled three-dimensional rou...
# 7     measurements of the effect of two-dimensional ...
# 8     transition studies and skin friction measureme...
# 9     the theory of the impact tube at low pressure ...
# 10    similar solutions in compressible laminar free...
# 11    some structural and aerelastic considerations ...
# 12    similarity laws for stressing heated wings .it...
# 13    piston theory - a new aerodynamic tool for the...
# 14    on two-dimensional panel flutter .theory and e...
# 15    transformation of the compressible turbulent b...
# 16    remarks on the eddy viscosity in compressible ...
# 17    the flow field in the diffuser of a radial com...
# 18    an investigation of the pressure distribution ...
# 19    generalised-newtonian theory .author generaliz...
# 20    on heat transfer in slip flow .a number of aut...
# 21    on slip-flow heat transfer to a flat plate .as...
# 22    skin-friction and heat transfer characteristic...
# 23    theory of stagnation point heat transfer in di...
# 24    inviscid hypersonic flow over blunt-nosed slen...
# 25    inviscid leading-edge effect in hypersonic flo...
# 26    newtonian flow theory for slender bodies .as a...
# 27    a note on the explosion solution of sedov with...
# 28    a simple model study of transient temperature ...
# 29    photo-thermoelastic investigation of transient...
# ...                                                 ...
# 1366  some remarks on the flat plate boundary layer ...
# 1367  axisymmetric free mixing with swirl .viscous l...
# 1368  on axially symmetric, turbulent, compressible ...
# 1369  nose drag in free-molecule flow and its minimi...
# 1370  theoretical analysis of turbulent mixing of re...
# 1371  an approximate solution for the axisymmetric j...
# 1372  some applications in physics of the p-function...
# 1373  theoretical investigation of the flow field ab...
# 1374  blunt-cone pressure distributions at hypersoni...
# 1375  hypersonic flight and the re-entry problem .pa...
# 1376  the problem of obtaining high lift-drag ratios...
# 1377  effect of mach number on boundary layer transi...
# 1378  the solution of the equations of the laminar b...
# 1379  on the theory of laminar boundary layer involv...
# 1380  a theoretical calculation of the laminar bound...
# 1381  air flow in a separating laminar boundary laye...
# 1382  analysis and calculation by integral methods o...
# 1383  the buckling of a square panel under shear, wh...
# 1384  a process for the step-by-step integration of ...
# 1385  numerical construction of detached shock waves...
# 1386  on the numerical calculation of detached bow s...
# 1387  shock wave and flow field development in hyper...
# 1388  the solution of small displacement, stability ...
# 1389  heat transfer near the forward stagnation poin...
# 1390  stagnation point heat transfer measurements in...
# 1391  low density stagnation point heat transfer mea...
# 1392  shear buckling of clamped and simply-supported...
# 1393  critical shear stress of an infinitely long si...
# 1394  stability of rectangular plates under shear an...
# 1395  buckling of transverse stiffened plates under ...
#
# [1396 rows x 5 columns]

# %%
documents.loc[239]
# Out:
# Id                                                  241
# T     laminar mixing of a non-uniform stream with a ...
# A                                             nash,j.f.
# B                                      arc 22245, 1960.
# W     laminar mixing of a non-uniform stream with a ...
# Name: 239, dtype: object

# %%
full_string_data = documents['T'].tolist() \
                 + documents['A'].tolist() \
                 + documents['B'].tolist() \
                 + queries['Query'].tolist()
                 # + documents['W'].tolist() \
                 

def create_features(data, documents, queries):
    docs_len = len(documents)
    vectorizer = HashingVectorizer(ngram_range=(1, 4), analyzer='word', n_features=2 ** 14, norm='l2')
    features = vectorizer.fit_transform(data).todense()
    doc_feachures = np.hstack((features[:docs_len], 
                               features[docs_len:2*docs_len], 
                               features[2*docs_len:3*docs_len], 
                               # features[3*docs_len:4*docs_len]
                              ))
    # query_features = features[4*docs_len:]
    query_features = features[3*docs_len:]
    doc_features_pd = pd.DataFrame(index=documents.Id.tolist(), data=doc_feachures)
    query_features_pd = pd.DataFrame(index=queries.QueryId.tolist(), data=query_features)
    return doc_features_pd, query_features_pd

# %%
doc_features, query_features = create_features(full_string_data, documents, queries)

# %%
features = []
test_features = []
ranks = []

for i in range(len(train_data)):
    doc_id = train_data.DocumentId.iloc[i]
    query_id = train_data.QueryId.iloc[i]
    if doc_id in doc_features.index and query_id in query_features.index:
        features.append(doc_features.loc[doc_id].tolist() + query_features.loc[query_id].tolist())
        ranks.append(train_data.Relevance.iloc[i])

# %%
def count_inversion_rate(predicted, real):
    l = len(real)
    result = 0
    for i in range(l):
        for j in range(l):
            if predicted[i] > predicted[j] and real[i] < real[j]:
                result += 1
    result = float(result)
    return result / float(l * (l - 1) / 2)

# %%
def dcg_at_k(r, k, method=0):
    r = np.asfarray(r)[:k]
    if r.size:
        if method == 0:
            return r[0] + np.sum(r[1:] / np.log2(np.arange(2, r.size + 1)))
        elif method == 1:
            return np.sum(r / np.log2(np.arange(2, r.size + 2)))
        else:
            raise ValueError('method must be 0 or 1.')
    return 0.


def ndcg_at_k(r, k=5, method=0):
    dcg_max = dcg_at_k(sorted(r, reverse=True), k, method)
    if not dcg_max:
        return 0.
    return dcg_at_k(r, k, method) / dcg_max

# %%
model = LogisticRegression(n_jobs=9, C=10, dual=True)
model.fit(features[:-50], ranks[:-50])
predicted = model.predict(features[-50:])
zip_sorted_list = np.array(sorted(list(zip(ranks[-50:], predicted))))
print(ndcg_at_k(zip_sorted_list[:,1]))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 9.
#   " = {}.".format(self.n_jobs))
# 0.426201811102

# %%
print(predicted)
# Out:
# [ 2  3  3  3  3  3 -1  3  1 -1  3 -1  2  3  3  3  3  3  2  3  3  3  3  3  2
#   3  3  3  3  3  3  3  3 -1  3  3  3  2  2  3  3  3  2 -1  3 -1  2  2  2  3]

# %%
result = []
for i in range(len(test_data)):
    doc_id = test_data.DocumentId.iloc[i]
    query_id = test_data.QueryId.iloc[i]
    if doc_id in doc_features.index and query_id in query_features.index:
        test_features = doc_features.loc[doc_id].tolist() + query_features.loc[query_id].tolist()
        result.append([query_id, (-1) * model.predict([test_features])[0], doc_id])
    else:
        result.append([query_id, np.random.rand(1)[0], doc_id])
        
result.sort()
result = np.array(result)

# %%
result.tofile
# Out:
# <function ndarray.tofile>

# %%
output = pd.DataFrame(data=result, columns=['QueryId', 'Rel', 'DocumentId'])

# %%
output = output.drop('Rel', axis=1)
output.to_csv("submission.tsv", sep=',', index=False)
